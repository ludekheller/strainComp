# %%
import sys
sys.path.append("/home/lheller/python")
from effective_elastic_constants_functions import  *
from projlib import  *
from crystallography_functions import *
from crystCalc import *
from plotlib import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
#size of the graph
plt.rcParams['figure.figsize'] = [35/2.45, 22/2.45]
SMALL_SIZE=11
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
#datafile to plot
fname="/home/lheller/Documents/papers/mypapers/AM_interface_under_stress/figures/pickle/criticalCpFig.pckl"
plotcolmaps(fname=fname)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
